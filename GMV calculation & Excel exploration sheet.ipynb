# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None
# Provide the file path
file_path = r'C:\Users\nzen4\Downloads\AdventureWorks Sales.xlsx'

# Read the Excel file into a DataFrame
df1 = pd.read_excel(file_path)

# Create an ExcelFile object
xls = pd.ExcelFile(file_path)

# Get the sheet names
sheet_names = xls.sheet_names

# Print the sheet names
for sheet_name in sheet_names:
    print(sheet_name)

# Now you can use the DataFrame 'df1' for further analysis or processing
# Out:
# Sales Order_data
# Sales Territory_data
# Sales_data
# Reseller_data
# Date_data
# Product_data
# Customer_data

# %%
#define all sheet
df_sales_order_data = pd.read_excel(xls,'Sales Order_data')
df_sales_territory_data = pd.read_excel(xls,'Sales Territory_data')  
df_sales_data = pd.read_excel(xls, 'Sales_data')
df_reseller_data = pd.read_excel(xls, 'Reseller_data')
df_date_data = pd.read_excel(xls, 'Date_data')
df_product_data = pd.read_excel(xls, 'Product_data')
df_customer_data = pd.read_excel(xls, 'Customer_data')

# %% [markdown]
# View Sheet 'Sales_data'

# %%
print(df_sales_order_data)
print(df_sales_territory_data)
print(df_sales_data)
print(df_reseller_data)
print(df_date_data)
print(df_product_data)
print(df_customer_data)
# Out:
#          Channel  SalesOrderLineKey Sales Order Sales Order Line
# 0       Reseller           43659001     SO43659      SO43659 - 1
# 1       Reseller           43659002     SO43659      SO43659 - 2
# 2       Reseller           43659003     SO43659      SO43659 - 3
# 3       Reseller           43659004     SO43659      SO43659 - 4
# 4       Reseller           43659005     SO43659      SO43659 - 5
# ...          ...                ...         ...              ...
# 121248  Internet           75122001     SO75122      SO75122 - 1
# 121249  Internet           75122002     SO75122      SO75122 - 2
# 121250  Internet           75123001     SO75123      SO75123 - 1
# 121251  Internet           75123002     SO75123      SO75123 - 2
# 121252  Internet           75123003     SO75123      SO75123 - 3
#
# [121253 rows x 4 columns]
#     SalesTerritoryKey          Region         Country          Group
# 0                   1       Northwest   United States  North America
# ...

# %%
print(df_sales_order_data.head(2))
print(df_sales_territory_data.head(2))
print(df_sales_data.head(2))
print(df_reseller_data.head(2))
print(df_date_data.head(2))
print(df_product_data.head(2))
print(df_customer_data.head(2))
# Out:
#     Channel  SalesOrderLineKey Sales Order Sales Order Line
# 0  Reseller           43659001     SO43659      SO43659 - 1
# 1  Reseller           43659002     SO43659      SO43659 - 2
#    SalesTerritoryKey     Region        Country          Group
# 0                  1  Northwest  United States  North America
# 1                  2  Northeast  United States  North America
#    SalesOrderLineKey  ResellerKey  CustomerKey  ProductKey  OrderDateKey  \
# 0           43659001          676           -1         349      20170702
# 1           43659002          676           -1         350      20170702
#
#    DueDateKey  ShipDateKey  SalesTerritoryKey  Order Quantity  Unit Price  \
# 0    20170712   20170709.0                  5               1    2024.994
# 1    20170712   20170709.0                  5               3    2024.994
#
#    Extended Amount  Unit Price Discount Pct  Product Standard Cost  \
# 0         2024.994                        0              1898.0944
# ...

# %%
GMV = df_sales_data['Sales Amount'].sum()
print('gmv = : ' , GMV)
# Out:
# gmv = :  109809274.203

# %%
mprovit = GMV-df_sales_data['Total Product Cost'].sum() - df_sales_data['Unit Price Discount Pct'].sum()
Net_Provit_Margin = (mprovit/GMV*100)
print('Net_Provit_Margin :',Net_Provit_Margin ,' %')
# Out:
# Net_Provit_Margin : 11.430151359617202  %

# %%
print(df_date_data.head(2))
# Out:
#     DateKey       Date Fiscal Year Fiscal Quarter     Month     Full Date  \
# 0  20170701 2017-07-01      FY2018      FY2018 Q1  2017 Jul  2017 Jul, 01
# 1  20170702 2017-07-02      FY2018      FY2018 Q1  2017 Jul  2017 Jul, 02
#
#    MonthKey
# 0    201707
# 1    201707
